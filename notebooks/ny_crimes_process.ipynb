# %%
# Import numpy, pandas, matpltlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
plt.style.use('ggplot')

# %%
# Import the data
df = pd.read_csv('./NYPD_Complaint_Data_Historic.csv')
df.info()
df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10472\1305390602.py:2: DtypeWarning: Columns (0,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./NYPD_Complaint_Data_Historic.csv')

# %%
import dask.dataframe as dd

df = dd.read_csv("NYPD_Complaint_Data_Historic.csv")
df.head()
df.describe().compute()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import dask.dataframe as dd
#       3 df = dd.read_csv("NYPD_Complaint_Data_Historic.csv")
#       4 df.head()
#
# ModuleNotFoundError: No module named 'dask'

# %%
df['CMPLNT_FR_DT']= pd.to_datetime(df['CMPLNT_FR_DT'],errors='coerce')
df.set_index('CMPLNT_FR_DT')
# Out:
#               CMPLNT_NUM CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  ADDR_PCT_CD  \
# CMPLNT_FR_DT
# 2014-09-04     724718389     17:25:00   09/04/2014     17:35:00         81.0
# 2016-10-12     191133903     07:40:00   10/12/2016     07:45:00        121.0
# 2012-09-28     720151206     13:30:00   09/28/2012     14:00:00         41.0
# 2015-03-24     232242098     15:45:00          NaN          NaN         46.0
# 2017-05-20     708078702     04:02:00   05/20/2017     04:09:00        109.0
# ...                  ...          ...          ...          ...          ...
# 2014-09-12     202934942     17:50:00   09/12/2014     17:55:00         28.0
# 2012-12-20     327134526     13:30:00   12/20/2012     13:35:00         70.0
# 2013-04-04     671421638     13:00:00   04/04/2013     15:30:00         90.0
# 2015-09-09     980011525     13:00:00   09/09/2015     13:50:00         13.0
# 2012-08-19     719347170     01:00:00   08/19/2012     01:30:00         73.0
#
# ...

# %%
df.info()
print (df.CMPLNT_FR_DT.min())
print (df.CMPLNT_FR_DT.max())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983207 entries, 0 to 6983206
# Data columns (total 35 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_NUM         int64
#  1   CMPLNT_FR_DT       datetime64[ns]
#  2   CMPLNT_FR_TM       object
#  3   CMPLNT_TO_DT       object
#  4   CMPLNT_TO_TM       object
#  5   ADDR_PCT_CD        float64
#  6   RPT_DT             object
#  7   KY_CD              int64
#  8   OFNS_DESC          object
#  9   PD_CD              float64
#  10  PD_DESC            object
#  11  CRM_ATPT_CPTD_CD   object
#  12  LAW_CAT_CD         object
#  13  BORO_NM            object
#  14  LOC_OF_OCCUR_DESC  object
#  15  PREM_TYP_DESC      object
#  16  JURIS_DESC         object
#  17  JURISDICTION_CODE  float64
#  18  PARKS_NM           object
#  19  HADEVELOPT         object
#  20  HOUSING_PSA        object
#  21  X_COORD_CD         float64
#  22  Y_COORD_CD         float64
#  23  SUSP_AGE_GROUP     object
# ...

# %%
#df['year'] = pd.DatetimeIndex(df['CMPLNT_FR_DT']).year
df['year']=df['CMPLNT_FR_DT'].dt.year

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983207 entries, 0 to 6983206
# Data columns (total 36 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_NUM         int64
#  1   CMPLNT_FR_DT       datetime64[ns]
#  2   CMPLNT_FR_TM       object
#  3   CMPLNT_TO_DT       object
#  4   CMPLNT_TO_TM       object
#  5   ADDR_PCT_CD        float64
#  6   RPT_DT             object
#  7   KY_CD              int64
#  8   OFNS_DESC          object
#  9   PD_CD              float64
#  10  PD_DESC            object
#  11  CRM_ATPT_CPTD_CD   object
#  12  LAW_CAT_CD         object
#  13  BORO_NM            object
#  14  LOC_OF_OCCUR_DESC  object
#  15  PREM_TYP_DESC      object
#  16  JURIS_DESC         object
#  17  JURISDICTION_CODE  float64
#  18  PARKS_NM           object
#  19  HADEVELOPT         object
#  20  HOUSING_PSA        object
#  21  X_COORD_CD         float64
#  22  Y_COORD_CD         float64
#  23  SUSP_AGE_GROUP     object
# ...

# %%
df.year.value_counts().sort_values(ascending=False)
# Out:
# 2007.0    535431
# 2006.0    529126
# 2008.0    528925
# 2009.0    511235
# 2010.0    510329
# 2012.0    504945
# 2011.0    498819
# 2013.0    496065
# 2014.0    492316
# 2015.0    479009
# 2016.0    478765
# 2018.0    477513
# 2017.0    469070
# 2019.0    450976
# 2005.0     10806
# 2004.0      2175
# 2003.0      1624
# 2002.0      1136
# 2001.0      1118
# 2000.0       939
# 1999.0       381
# 1998.0       280
# 1996.0       153
# 1997.0       152
# 1995.0       108
# 1994.0        97
# 1993.0        72
# 1992.0        63
# 1991.0        54
# 1990.0        47
# 1989.0        44
# 1986.0        38
# 1985.0        37
# 1979.0        29
# 1966.0        27
# 1977.0        26
# 1988.0        25
# 1987.0        25
# 1975.0        25
# 1980.0        21
# 1974.0        19
# 1983.0        19
# 1984.0        19
# 1981.0        17
# 1973.0        15
# 1972.0        15
# 1967.0        14
# 1968.0        14
# 1971.0        14
# 1970.0        13
# 1978.0        13
# 1982.0        13
# ...

# %%
aYear=2019
df_sel=df[df.year == aYear]

# %%
df_sel.head()
df_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450976 entries, 4076870 to 4541915
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         450976 non-null  int64
#  1   CMPLNT_FR_DT       450976 non-null  datetime64[ns]
#  2   CMPLNT_FR_TM       450976 non-null  object
#  3   CMPLNT_TO_DT       394679 non-null  object
#  4   CMPLNT_TO_TM       394912 non-null  object
#  5   ADDR_PCT_CD        450976 non-null  float64
#  6   RPT_DT             450976 non-null  object
#  7   KY_CD              450976 non-null  int64
#  8   OFNS_DESC          450968 non-null  object
#  9   PD_CD              450684 non-null  float64
#  10  PD_DESC            450684 non-null  object
#  11  CRM_ATPT_CPTD_CD   450976 non-null  object
#  12  LAW_CAT_CD         450976 non-null  object
#  13  BORO_NM            450677 non-null  object
#  14  LOC_OF_OCCUR_DESC  369242 non-null  object
# ...

# %%
df_sel.dropna(subset=['CMPLNT_FR_DT'])
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 4076870   552996231   2019-01-01     16:25:00          NaN          NaN
# 4076872   807279950   2019-01-02     19:50:00          NaN          NaN
# 4076873   508802958   2019-01-02     22:00:00   01/02/2019     22:10:00
# 4076876   259858195   2019-01-02     19:45:00   01/03/2019     09:30:00
# 4076877   531549247   2019-01-03     15:01:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 4541911   333362495   2019-12-22     20:45:00   12/22/2019     20:50:00
# 4541912   152668204   2019-12-30     22:50:00          NaN          NaN
# 4541913   915496604   2019-12-27     17:47:00   12/27/2019     18:14:00
# 4541914   670991668   2019-12-29     05:10:00   12/29/2019     05:15:00
# 4541915   549985927   2019-12-11     23:10:00   12/11/2019     23:10:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                     OFNS_DESC  PD_CD  \
# ...

# %%
df_sel.head()
df_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 450976 entries, 4076870 to 4541915
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         450976 non-null  int64
#  1   CMPLNT_FR_DT       450976 non-null  datetime64[ns]
#  2   CMPLNT_FR_TM       450976 non-null  object
#  3   CMPLNT_TO_DT       394679 non-null  object
#  4   CMPLNT_TO_TM       394912 non-null  object
#  5   ADDR_PCT_CD        450976 non-null  float64
#  6   RPT_DT             450976 non-null  object
#  7   KY_CD              450976 non-null  int64
#  8   OFNS_DESC          450968 non-null  object
#  9   PD_CD              450684 non-null  float64
#  10  PD_DESC            450684 non-null  object
#  11  CRM_ATPT_CPTD_CD   450976 non-null  object
#  12  LAW_CAT_CD         450976 non-null  object
#  13  BORO_NM            450677 non-null  object
#  14  LOC_OF_OCCUR_DESC  369242 non-null  object
# ...

# %%
df_sel.to_csv('./NYPD_Complaint_Data_Historic_'+str(aYear)+'.csv',index=False)
